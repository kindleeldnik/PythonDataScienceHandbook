# %%
import numpy as np

# %%
L = np.random.random(100)
sum(L)
# Out:
# 49.686974857659692

# %%
big_array = np.random.rand(1000000)

# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 92.8 ms ± 3.13 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 660 µs ± 3.02 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
min(big_array), max(big_array)
# Out:
# (8.2506517518066147e-07, 0.99999831304676856)

# %%
np.min(big_array), np.max(big_array)
# Out:
# (8.2506517518066147e-07, 0.99999831304676856)

# %%
# %timeit min(big_array)
# %timeit np.min(big_array)
# Out:
# 78 ms ± 2.33 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 685 µs ± 1.24 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
print(big_array.min(), big_array.max(), big_array.sum())
# Out:
# 8.25065175181e-07 0.999998313047 499865.747444

# %%
M = np.random.random((3, 4))
print(M)
# Out:
# [[ 0.75003124  0.58416439  0.69443279  0.17992041]
#  [ 0.55882757  0.34378565  0.8673971   0.93241465]
#  [ 0.43722048  0.24895672  0.81839558  0.24695446]]

# %%
M.sum()
# Out:
# 6.6625010401628071

# %%
M.min(axis=0)
# Out:
# array([ 0.43722048,  0.24895672,  0.69443279,  0.17992041])

# %%
M.min(axis=1)
# Out:
# array([ 0.17992041,  0.34378565,  0.24695446])

# %%
# !head -4 president_heights.csv
# Out:
# order,name,height(cm)
# 1,George Washington,189
# 2,John Adams,170
# 3,Thomas Jefferson,189

# %%
import pandas as pd
data = pd.read_csv("president_heights.csv")
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185]

# %%
print("Mean heights:          ", heights.mean())
print("Standard deviation     ", heights.std())
print("Minimum height         ", heights.min())
print("Maximum height         ", heights.max())
# Out:
# Mean heights:           179.738095238
# Standard deviation      6.93184344275
# Minimum height          163
# Maximum height          193

# %%
print("25th percentitile:  ", np.percentile(heights, 25))
print("Median:             ", np.median(heights))
print("75th percentitile:  ", np.percentile(heights, 75))
# Out:
# 25th percentitile:   174.25
# Median:              182.0
# 75th percentitile:   183.0

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn; 
seaborn.set()

# %%
plt.hist(heights)
plt.title("Height Distribution of US Presidents")
plt.xlabel('height cm')
plt.ylabel('number')
# Out:
# Text(0,0.5,'number')
